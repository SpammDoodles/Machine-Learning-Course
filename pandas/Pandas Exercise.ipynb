# %%
import pandas as pd

# %%
colors = pd.Series(["Blue","Black","Brown"])

# %%
colors
# Out:
# 0     Blue
# 1    Black
# 2    Brown
# dtype: object

# %%
cars = pd.Series(["Honda","Tyota","BMW"])

# %%
car_data = pd.DataFrame({"Cars" : cars,"Colors" : colors})
car_data
# Out:
#     Cars Colors
# 0  Honda   Blue
# 1  Tyota  Black
# 2    BMW  Brown

# %%
df = pd.read_csv("car-sales.csv")
df
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00
# 7   Honda   Blue          54738      4   $7,000.00
# 8  Toyota  White          60000      4   $6,250.00
# 9  Nissan  White          31600      4   $9,700.00

# %%
car_data.to_csv("car-data.csv")

# %%
df.dtypes
# Out:
# Make             object
# Colour           object
# Odometer (KM)     int64
# Doors             int64
# Price            object
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           10 non-null     object
#  1   Colour         10 non-null     object
#  2   Odometer (KM)  10 non-null     int64
#  3   Doors          10 non-null     int64
#  4   Price          10 non-null     object
# dtypes: int64(2), object(3)
# memory usage: 532.0+ bytes

# %%
df.describe()
# Out:
#        Odometer (KM)      Doors
# count      10.000000  10.000000
# mean    78601.400000   4.000000
# std     61983.471735   0.471405
# min     11179.000000   3.000000
# 25%     35836.250000   4.000000
# 50%     57369.000000   4.000000
# 75%     96384.500000   4.000000
# max    213095.000000   5.000000

# %%
numbers = pd.Series([11,21,45,67,34,23,45,23,45])
numbers.mean()
# Out:
# 34.888888888888886

# %%
numbers = pd.Series([34,12,34,45,23,56,67])
numbers.sum()
# Out:
# 271

# %%
list(df.columns)
# Out:
# ['Make', 'Colour', 'Odometer (KM)', 'Doors', 'Price']

# %%
df.shape[0]
# Out:
# 10

# %%
df.head(5)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00

# %%
df.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors       Price
# 0  Toyota  White         150043      4   $4,000.00
# 1   Honda    Red          87899      4   $5,000.00
# 2  Toyota   Blue          32549      3   $7,000.00
# 3     BMW  Black          11179      5  $22,000.00
# 4  Nissan  White         213095      4   $3,500.00
# 5  Toyota  Green          99213      4   $4,500.00
# 6   Honda   Blue          45698      4   $7,500.00

# %%
df.tail(5)
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 5  Toyota  Green          99213      4  $4,500.00
# 6   Honda   Blue          45698      4  $7,500.00
# 7   Honda   Blue          54738      4  $7,000.00
# 8  Toyota  White          60000      4  $6,250.00
# 9  Nissan  White          31600      4  $9,700.00

# %%
df.iloc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
df.loc[3]
# Out:
# Make                    BMW
# Colour                Black
# Odometer (KM)         11179
# Doors                     5
# Price            $22,000.00
# Name: 3, dtype: object

# %%
df["Odometer (KM)"]
# Out:
# 0    150043
# 1     87899
# 2     32549
# 3     11179
# 4    213095
# 5     99213
# 6     45698
# 7     54738
# 8     60000
# 9     31600
# Name: Odometer (KM), dtype: int64

# %%
df["Odometer (KM)"].mean()
# Out:
# 78601.4

# %%
df[df["Odometer (KM)"] > 100000]
# Out:
#      Make Colour  Odometer (KM)  Doors      Price
# 0  Toyota  White         150043      4  $4,000.00
# 4  Nissan  White         213095      4  $3,500.00

# %%
pd.crosstab(df["Make"],df["Doors"])
# Out:
# Doors   3  4  5
# Make
# BMW     0  0  1
# Honda   0  3  0
# Nissan  0  2  0
# Toyota  1  3  0

# %%
df.groupby("Make").mean(numeric_only = True)
# Out:
#         Odometer (KM)  Doors
# Make
# BMW      11179.000000   5.00
# Honda    62778.333333   4.00
# Nissan  122347.500000   4.00
# Toyota   85451.250000   3.75

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
df.plot()
plt.show()

# %%
df.hist()
plt.show()

# %%
plt.plot(df["Price"])
plt.show()

# %%
df["Price"] = df["Price"].str.replace(r"[$/,.]","",regex = True)
df["Price"] = pd.to_numeric(df["Price"], errors = "coerce")

# %%
df["Price"].plot()
plt.show()

# %%
df["Price"].dtype
# Out:
# dtype('int64')

# %%
df["Make"].str.lower()
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
df["Make"]
# Out:
# 0    Toyota
# 1     Honda
# 2    Toyota
# 3       BMW
# 4    Nissan
# 5    Toyota
# 6     Honda
# 7     Honda
# 8    Toyota
# 9    Nissan
# Name: Make, dtype: object

# %%
df["Make"] = df["Make"].str.lower()
df["Make"]
# Out:
# 0    toyota
# 1     honda
# 2    toyota
# 3       bmw
# 4    nissan
# 5    toyota
# 6     honda
# 7     honda
# 8    toyota
# 9    nissan
# Name: Make, dtype: object

# %%
car_sales_missing_data = pd.read_csv("car-sales-extended-missing-data.csv")
car_sales_missing_data
# Out:
#        Make Colour  Odometer (KM)  Doors    Price
# 0     Honda  White        35431.0    4.0  15323.0
# 1       BMW   Blue       192714.0    5.0  19943.0
# 2     Honda  White        84714.0    4.0  28343.0
# 3    Toyota  White       154365.0    4.0  13434.0
# 4    Nissan   Blue       181577.0    3.0  14043.0
# ..      ...    ...            ...    ...      ...
# 995  Toyota  Black        35820.0    4.0  32042.0
# 996     NaN  White       155144.0    3.0   5716.0
# 997  Nissan   Blue        66604.0    4.0  31570.0
# 998   Honda  White       215883.0    4.0   4001.0
# 999  Toyota   Blue       248360.0    4.0  12732.0
#
# [1000 rows x 5 columns]

# %%
car_sales_missing_data["Odometer (KM)"] = car_sales_missing_data["Odometer (KM)"].fillna(car_sales_missing_data["Odometer (KM)"].mean())

# %%
car_sales_missing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           951 non-null    object
#  1   Colour         950 non-null    object
#  2   Odometer (KM)  1000 non-null   float64
#  3   Doors          950 non-null    float64
#  4   Price          950 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 39.2+ KB

# %%
car_sales_missing_data.dropna(inplace = True)

# %%
car_sales_missing_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 815 entries, 0 to 999
# Data columns (total 5 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Make           815 non-null    object
#  1   Colour         815 non-null    object
#  2   Odometer (KM)  815 non-null    float64
#  3   Doors          815 non-null    float64
#  4   Price          815 non-null    float64
# dtypes: float64(3), object(2)
# memory usage: 38.2+ KB

# %%
car_sales_missing_data.isna().sum()
# Out:
# Make             0
# Colour           0
# Odometer (KM)    0
# Doors            0
# Price            0
# dtype: int64

# %%
car_sales_missing_data["Seats"] = 5
car_sales_missing_data
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats
# 0     Honda  White        35431.0    4.0  15323.0      5
# 1       BMW   Blue       192714.0    5.0  19943.0      5
# 2     Honda  White        84714.0    4.0  28343.0      5
# 3    Toyota  White       154365.0    4.0  13434.0      5
# 4    Nissan   Blue       181577.0    3.0  14043.0      5
# ..      ...    ...            ...    ...      ...    ...
# 994     BMW   Blue       163322.0    3.0  31666.0      5
# 995  Toyota  Black        35820.0    4.0  32042.0      5
# 997  Nissan   Blue        66604.0    4.0  31570.0      5
# 998   Honda  White       215883.0    4.0   4001.0      5
# 999  Toyota   Blue       248360.0    4.0  12732.0      5
#
# [815 rows x 6 columns]

# %%
import numpy as np
car_sales_missing_data["Engine Size"] = np.random.uniform(1.3,4.5,car_sales_missing_data.shape[0])

# %%
car_sales_missing_data.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Engine Size
# 0   Honda  White        35431.0    4.0  15323.0      5     2.553681
# 1     BMW   Blue       192714.0    5.0  19943.0      5     2.843909
# 2   Honda  White        84714.0    4.0  28343.0      5     4.452045
# 3  Toyota  White       154365.0    4.0  13434.0      5     2.460361
# 4  Nissan   Blue       181577.0    3.0  14043.0      5     3.809277

# %%
car_sales_missing_data["Price per KM"] = car_sales_missing_data["Price"] / car_sales_missing_data["Odometer (KM)"]
car_sales_missing_data.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Engine Size  \
# 0   Honda  White        35431.0    4.0  15323.0      5     2.553681
# 1     BMW   Blue       192714.0    5.0  19943.0      5     2.843909
# 2   Honda  White        84714.0    4.0  28343.0      5     4.452045
# 3  Toyota  White       154365.0    4.0  13434.0      5     2.460361
# 4  Nissan   Blue       181577.0    3.0  14043.0      5     3.809277
#
#    Price per KM
# 0      0.432474
# 1      0.103485
# 2      0.334573
# 3      0.087027
# 4      0.077339

# %%
car_sales_missing_data.drop("Price per KM",axis = 1,inplace = True)
car_sales_missing_data.head(7)
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Engine Size
# 0   Honda  White        35431.0    4.0  15323.0      5     2.553681
# 1     BMW   Blue       192714.0    5.0  19943.0      5     2.843909
# 2   Honda  White        84714.0    4.0  28343.0      5     4.452045
# 3  Toyota  White       154365.0    4.0  13434.0      5     2.460361
# 4  Nissan   Blue       181577.0    3.0  14043.0      5     3.809277
# 5   Honda    Red        42652.0    4.0  23883.0      5     1.469228
# 6  Toyota   Blue       163453.0    4.0   8473.0      5     2.947377

# %%
shuffled_sales_data = car_sales_missing_data.sample(frac = 1)
shuffled_sales_data.head()
# Out:
#        Make Colour  Odometer (KM)  Doors    Price  Seats  Engine Size
# 17      BMW  White       194189.0    5.0  17177.0      5     1.469902
# 846  Toyota  White        93593.0    4.0  29638.0      5     3.284652
# 70   Nissan  White       123121.0    4.0  22436.0      5     2.959517
# 366   Honda  White       213324.0    4.0   8704.0      5     3.533110
# 775   Honda   Blue        63800.0    4.0  26308.0      5     1.752241

# %%
shuffled_sales_data.reset_index(drop = True,inplace = True)

# %%
shuffled_sales_data.head()
# Out:
#      Make Colour  Odometer (KM)  Doors    Price  Seats  Engine Size
# 0     BMW  White       194189.0    5.0  17177.0      5     1.469902
# 1  Toyota  White        93593.0    4.0  29638.0      5     3.284652
# 2  Nissan  White       123121.0    4.0  22436.0      5     2.959517
# 3   Honda  White       213324.0    4.0   8704.0      5     3.533110
# 4   Honda   Blue        63800.0    4.0  26308.0      5     1.752241

# %%
car_sales_missing_data["Odometer (KM)"] = car_sales_missing_data["Odometer (KM)"].apply(lambda x: x * 0.63)
car_sales_missing_data.rename(columns = {"Odometer (KM)" : "Odometer (Miles)"},inplace = True)

# %%
car_sales_missing_data.head()
# Out:
#      Make Colour  Odometer (Miles)  Doors    Price  Seats  Engine Size
# 0   Honda  White       5581.431612    4.0  15323.0      5     2.553681
# 1     BMW   Blue      30358.161262    5.0  19943.0      5     2.843909
# 2   Honda  White      13344.963382    4.0  28343.0      5     4.452045
# 3  Toyota  White      24317.058248    4.0  13434.0      5     2.460361
# 4  Nissan   Blue      28603.753995    3.0  14043.0      5     3.809277
